# %%
import cv2
from cv2 import imread
import random
import numpy as np
import urllib.request
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %%
# !wget "https://upload.wikimedia.org/wikipedia/commons/3/3f/JPEG_example_flower.jpg"
# Out:
# --2025-03-30 20:07:29--  https://upload.wikimedia.org/wikipedia/commons/3/3f/JPEG_example_flower.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 198.35.26.112, 2620:0:863:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|198.35.26.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 36287 (35K) [image/jpeg]
# Saving to: ‘JPEG_example_flower.jpg.2’
#
# JPEG_example_flower 100%[===================>]  35.44K  --.-KB/s    in 0.02s
#
# 2025-03-30 20:07:29 (1.60 MB/s) - ‘JPEG_example_flower.jpg.2’ saved [36287/36287]

# %%
img= imread ("JPEG_example_flower.jpg")
plt.imshow(img)
plt.show()

# %%
img[400:150]
# Out:
# array([], shape=(0, 500, 3), dtype=uint8)

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
img_rgb[0, 0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
def data_img(img):
  print('Tamaño = ',img.shape)
  print('Max  = ',np.max(img))
  print('Min  = ',np.min(img))

data_img(img)
# Out:
# Tamaño =  (477, 500, 3)
# Max  =  255
# Min  =  0

# %%
# Primero alto, despues ancho
img_cropped = img[150:550, 150:550]
plt.imshow(img_cropped)

# %%
plt.imshow(img_rgb)
plt.show()

# %%
img_rgb[0,0]
# Out:
# array([255, 255, 255], dtype=uint8)

# %%
# Primero ancho y despues alto
img_resize = cv2.resize(img_cropped, (60, 60))
plt.imshow(img_resize)

# %%
img_canny = cv2.Canny(img_resize, 150, 300)
plt.imshow(img_canny)

# %%
X = img_cropped[:,:,0]
data_img(X)
# Out:
# Tamaño =  (327, 350)
# Max  =  255
# Min  =  0

# %%
plt.imshow(X,cmap='gray')
plt.show()
